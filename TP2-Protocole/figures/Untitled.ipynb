# %%
import numpy as np

#Paramètres
a0 = 2.301
a1 = 21.04
a2 = 11.62 * 10**(-2)
a3 = -40.48 * 10**(-4)
a4 = 1.537 * 10**(-4)

I_DEL = lambda P : a0 + a1 * P + a2 * P**2 + a3 * P**3 + a4 * P**4

# %%
P_in = np.array([0, 5, 10, 15, 20, 25])
I_DEL(P_in)
# Out:
# array([  2.301    , 109.9960625, 221.81     , 338.1650625, 461.789    ,
#        597.7150625])

# %%
eta_1 = 0.325
eta_2 = 0.140


print(eta_1 / eta_2 * P_in)
# Out:
# [ 0.         11.60714286 23.21428571 34.82142857 46.42857143 58.03571429]
